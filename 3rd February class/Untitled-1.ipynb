# %%
import numpy as np
import pandas as pd
filepath = "C:\\Muhammad Qasim Ashfaq\\University 3A\\Data Science\\3rd February class\\winequality-red.csv"
data = pd.read_csv(filepath,sep = ";")
# ensure we have numeric columns (CSV uses ';' as separator)


# compute row-wise mean (ignores NaNs)
dummy = data.mean(axis=0)
print(dummy)
# Out:
# fixed acidity            8.319637
# volatile acidity         0.527821
# citric acid              0.270976
# residual sugar           2.538806
# chlorides                0.087467
# free sulfur dioxide     15.874922
# total sulfur dioxide    46.467792
# density                  0.996747
# pH                       3.311113
# sulphates                0.658149
# alcohol                 10.422983
# quality                  5.636023
# dtype: float64
